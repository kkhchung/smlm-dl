# %%
# %pylab inline
# %load_ext line_profiler

from importlib import reload

import scipy
from scipy import interpolate
import skimage

import torch

from smlm_dl import model, spline, util, dataset
from smlm_dl.model import renderer
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n = 11
fig, axes = subplots(1, 1, figsize=(8,5))
bs = np.linspace(0, 1, n)
for b in bs:
    # print(b)
    # print()
    axes.plot(spline.calculate_bspline_basis(b, k=3), label="{:.2f}".format(b))
    
legend()

# %%
reload(spline)
spline.test_calculate_bspline_basis_fast_mode()

# %lprun -f spline.test_calculate_bspline_basis_fast_mode spline.test_calculate_bspline_basis_fast_mode()
# Out:
# PASSED all 1000 runs.
# PASSED all 1000 runs.
# Timer unit: 1e-07 s
#
# Total time: 0.649915 s
# File: d:\github\smlm-dl\smlm_dl\spline.py
# Function: test_calculate_bspline_basis_fast_mode at line 150
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    150                                           def test_calculate_bspline_basis_fast_mode(iter=1000):
#    151         1       1456.0   1456.0      0.0      ks = np.random.randint(1, 4, size=iter)
#    152         1         26.0     26.0      0.0      allclose = True
#    153      1001       7637.0      7.6      0.1      for i in range(iter):
#    154      1000      99019.0     99.0      1.5          p = np.random.rand(9)
#    155      1000     313516.0    313.5      4.8          res_fast = calculate_bspline_basis(p, ks[i], True)
#    156      1000    2911269.0   2911.3     44.8          res_slow = calculate_bspline_basis(p, ks[i], False)
#    157      1000    3151609.0   3151.6     48.5          same = all([np.allclose(a, b) for a, b in zip(res_fast, res_slow)])
#    158      1000      13298.0     13.3      0.2          if same is False:
#    159                                                       allclose = False
#    160                                                       print("FAILED\tk={},\nfast: {}\nslow: {}".format(ks[i], res_fast, res_slow))
#    161         1          6.0      6.0      0.0      if allclose is True:
#    162         1       1312.0   1312.0      0.0          print("PASSED all {} runs.".format(iter))

# %%
image = skimage.data.human_mitosis()[112:160, 96:128].astype(np.float)
imshow(image)
print(image.shape)
# Out:
# (48, 32)
# C:\Users\Kenny\AppData\Local\Temp/ipykernel_32004/1027288082.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   image = skimage.data.human_mitosis()[112:160, 96:128].astype(np.float)

# %%
reload(renderer)
# spline_model = spline.Spline2D(image, k=3, fit_image=False)
spline_model = renderer.Spline2DRenderer(image.shape, [], k=3, template_init=image)

image_interpolated = spline_model.render(1).detach().numpy()

fig, axes = subplots(1, 3, figsize=(15, 5))
im = axes[0].imshow(image)
colorbar(im, ax=axes[0])
im = axes[1].imshow(image_interpolated)
colorbar(im, ax=axes[1])
im = axes[2].imshow(np.log10(image_interpolated-image))
colorbar(im, ax=axes[2])
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# C:\Users\Kenny\anaconda3\envs\smlm-dl\lib\site-packages\torch\autograd\__init__.py:154: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 6050). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  ..\c10\cuda\CUDAFunctions.cpp:112.)
#   Variable._execution_engine.run_backward(
# Final loss: 0.856	R2: 0.998
# C:\Users\Kenny\AppData\Local\Temp/ipykernel_32004/295166216.py:12: RuntimeWarning: invalid value encountered in log10
#   im = axes[2].imshow(np.log10(image_interpolated-image))

# %%
reload(renderer)
# spline_model = spline.Spline2D(image, k=3, fit_image=True)
spline_model = renderer.Spline2DRenderer(image.shape, [], k=3, template_init=image)

# image_interpolated = spline_model.render(1)

fig, axes = subplots(1, 4, figsize=(20, 6))
for i in range(4):
    axes[i].imshow(spline_model.render(2**i).detach().numpy())
    axes[i].set_title("{}x".format(2**i))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Final loss: 0.856	R2: 0.998

# %%
reload(renderer)
print(image.shape)
# spline_model = spline.Spline2D(image, k=3, out_size=(64,64), fit_image=True)
padding=8
spline_model = renderer.Spline2DRenderer([dim+2*padding for dim in image.shape], [], k=3, template_init=image)

x = dict()
x['x'] = (torch.rand((128, 1, 1, 1)) - 0.5) * 10
x['y'] = (torch.rand((128, 1, 1, 1)) - 0.5) * 10
x['A'] = 1
x['bg'] = 0
image_interpolated = spline_model(x).detach().numpy()

n = 5
fig, axes = subplots(3, n, figsize=(5*n, 5*3))
for i, j in enumerate(np.linspace(0, image_interpolated.shape[2]-1, n)):    
    j = int(floor(j))
    
    axes[0,i].imshow(image_interpolated[j,0,:,:])
    # z_index = min(int(floor(x['z'][j])), volume.shape[2]-1)
    groundtruth = np.pad(image, ((padding,)*2, (padding,)*2))
    axes[1,i].imshow(groundtruth)
    axes[2,i].imshow(image_interpolated[j,0,:,:]-groundtruth)
    
# %lprun -f spline_model._render_images -f spline_model._calculate_template spline_model(x)
# Out:
# (48, 32)
#   0%|          | 0/100 [00:00<?, ?it/s]
# Final loss: 0.856	R2: 0.998
# Timer unit: 1e-07 s
#
# Total time: 0.0256131 s
# File: d:\github\smlm-dl\smlm_dl\model\renderer.py
# Function: _render_images at line 345
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    345                                               def _render_images(self, mapped_params, batch_size=None, raw=False):
#    346         1       2685.0   2685.0      1.0          shift_pixel = {key: torch.floor(mapped_params[key]/1).type(torch.int) for key in ['x', 'y']}
#    347         1       1062.0   1062.0      0.4          shifts_subpixel = {key: torch.remainder(mapped_params[key], 1) for key in ['x', 'y']}
#    348
#    349         1     109328.0 109328.0     42.7          template = self._calculate_template(shifts_subpixel)
#    350         1         24.0     24.0      0.0          if raw:
#    351                                                       return template
#    352
#    353         1       4375.0   4375.0      1.7          x_a = torch.zeros((shift_pixel['y'].shape[0], shift_pixel['y'].shape[1], self.out_size[0]+2, self.out_size[1]+2))
#    354
#    355         4      21272.0   5318.0      8.3          index = self.index_a.unsqueeze(0).unsqueeze(0) \
#    356         1         30.0     30.0      0.0                  + shift_pixel['y'] \
#    357         2         94.0     47.0      0.0                  + self.centering_offset[1] + 1
#    358         1       7429.0   7429.0      2.9          index = torch.clamp(index, 0, x_a.shape[3]-1)
#    359                                                   # print(x_a.shape, index.shape, template.shape)
#    360         1       5561.0   5561.0      2.2          x_a.scatter_(3, index, template)
#    361
#    362         1       4665.0   4665.0      1.8          x_b = torch.zeros_like(x_a)
#    363
#    364         4      41092.0  10273.0     16.0          index = self.index_b.unsqueeze(0).unsqueeze(0) \
#    365         1        130.0    130.0      0.1                  + shift_pixel['x'] \
#    366         2        141.0     70.5      0.1                  + self.centering_offset[0] + 1
#    367         1      12971.0  12971.0      5.1          index = torch.clamp(index, 0, x_b.shape[2]-1)
#    368                                                   # print(x_b.shape, index.shape, template.shape)
#    369         1      28288.0  28288.0     11.0          x_b.scatter_(2, index, x_a)
#    370
#    371         1        939.0    939.0      0.4          x = x_b[:,:,1:-1,1:-1]
#    372
#    373         1      16013.0  16013.0      6.3          x = x * mapped_params['A'] + mapped_params['bg']
#    374
#    375         1         32.0     32.0      0.0          return x
#
# Total time: 0.0107492 s
# File: d:\github\smlm-dl\smlm_dl\model\renderer.py
# Function: _calculate_template at line 377
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    377                                               def _calculate_template(self, shifts_subpixel):
#    378         1      10778.0  10778.0     10.0          bases = {key: spline.calculate_bspline_basis(val, self.k) for key, val in shifts_subpixel.items()}
#    379         1         24.0     24.0      0.0          x = 0
#    380         5        112.0     22.4      0.1          for i, cx in enumerate(bases['x']):
#    381        20        777.0     38.9      0.7              for j, cy in enumerate(bases['y']):
#    382        32       8273.0    258.5      7.7                  coeffs = self.coeffs[i+self.offset:i+self.offset+self.template_size[0]+1,
#    383        16        461.0     28.8      0.4                                       j+self.offset:j+self.offset+self.template_size[1]+1]
#    384        16      87057.0   5441.1     81.0                  x = x + cx * cy * coeffs
#    385         1         10.0     10.0      0.0          return x

# %%
volume = skimage.data.cells3d()[15:-15,1,128:128+64,192:192+64].astype(np.float32)
volume = np.moveaxis(volume, 0, -1)
print(volume.shape)

n=5
fig, axes = subplots(1, n, figsize=(4*n, 4))
for i, j in enumerate(np.linspace(0, volume.shape[2]-1, n)):
    j = np.floor(j).astype(int)
    axes[i].imshow(volume[:,:,j])
    axes[i].set_title("ind:{}".format(j))
# Out:
# (64, 64, 30)

# %%
reload(renderer)
spline_model = renderer.Spline3DRenderer(volume.shape[:2], [], k=3, template_init=volume)

volume_interpolated = spline_model.render(1).detach().numpy()

n = 7
fig, axes = subplots(3, n, figsize=(n*4, 3*4))
for i, j in enumerate(np.linspace(0, volume.shape[2]-1, n)):
    j = int(floor(j))
    
    im=axes[0,i].imshow(volume[:,:,j])
    colorbar(im, ax=axes[0,i])
    axes[0,i].set_title("ind:{}".format(j))
    
    im=axes[1,i].imshow(volume_interpolated[:,:,j])
    colorbar(im, ax=axes[1,i])
    axes[1,i].set_title("ind:{}".format(j))
    
    im=axes[2,i].imshow(volume_interpolated[:,:,j] / volume[:,:,j])
    colorbar(im, ax=axes[2,i])
    axes[2,i].set_title("ind:{}".format(j))
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Final loss: 212740.734	R2: 0.992

# %%
scale = 4
volume_interpolated = spline_model.render(scale).detach().numpy()

vmin = min(volume.min(), volume_interpolated.min())
vmax = max(volume.max(), volume_interpolated.max())

n = 5
fig, axes = subplots(2, n, figsize=(n*4, 3*3))
for i, j in enumerate(np.linspace(0, volume.shape[2]-1, n)):
    j = int(floor(j))
    im=axes[0,i].imshow(volume[:,:,j], vmin=vmin, vmax=vmax)
    colorbar(im, ax=axes[0,i])
    axes[0,i].set_title("ind:{}".format(j))
    
for i, j in enumerate(np.linspace(0, volume_interpolated.shape[2]-scale, n)):
    j = int(floor(j))
    im=axes[1,i].imshow(volume_interpolated[:,:,j], vmin=vmin, vmax=vmax)
    colorbar(im, ax=axes[1,i])
    axes[1,i].set_title("ind:{}".format(j))

# %%
reload(renderer)
print(volume.shape)
padding = 16
spline_model = renderer.Spline3DRenderer([dim+2*padding for dim in volume.shape[:2]], [], k=3, template_init=volume)

print(volume.shape)

x = dict()
x['x'] = (torch.rand((128, 1, 1, 1)) - 0.5) * 2 * 50
x['y'] = (torch.rand((128, 1, 1, 1)) - 0.5) * 2 * 50
x['z'] = torch.rand((128, 1, 1, 1)) * volume.shape[2] - volume.shape[2]//2
x['A'] = 1
x['bg'] = 0
volume_interpolated = spline_model(x).detach().numpy()

vmin = min(volume.min(), volume_interpolated.min())
vmax = max(volume.max(), volume_interpolated.max())

n = 5
fig, axes = subplots(3, n, figsize=(5*n, 5*3))
for i, j in enumerate(np.linspace(0, volume_interpolated.shape[0]-1, n)):
    j = int(floor(j))
    
    axes[0,i].imshow(volume_interpolated[j,0,:,:], vmin=vmin, vmax=vmax)
    z_index = min(int(floor(x['z'][j] + volume.shape[2]//2)), volume.shape[2]-1)
    groundtruth = np.pad(volume[:,:,z_index], ((padding,)*2, (padding,)*2))
    axes[1,i].imshow(groundtruth, vmin=vmin, vmax=vmax)
    axes[2,i].imshow(volume_interpolated[j,0,:,:]-groundtruth)
# Out:
# (64, 64, 30)
#   0%|          | 0/50 [00:00<?, ?it/s]
# Final loss: 212740.734	R2: 0.992
# (64, 64, 30)

# %%
reload(renderer)
print(volume.shape)
padding = 16
spline_model = renderer.Spline3DRenderer(volume.shape[:2], [], k=3, template_init=volume[:32,:32])

x = dict()
x['x'] = (torch.rand((1024, 1, 1, 1)) - 0.5) * 2 * 50
x['y'] = (torch.rand((1024, 1, 1, 1)) - 0.5) * 2 * 50
x['z'] = torch.rand((1024, 1, 1, 1)) * volume.shape[2]
x['A'] = 1
x['bg'] = 0

# %prun volume_interpolated = spline_model(x)
# %lprun -f spline_model.render_images -f spline_model._render_images -f spline_model._calculate_template spline_model(x)
# Out:
# (64, 64, 30)
#   0%|          | 0/50 [00:00<?, ?it/s]
# Final loss: 507975.031	R2: 0.984
# Timer unit: 1e-07 s
#
# Total time: 0.705941 s
# File: d:\github\smlm-dl\smlm_dl\model\renderer.py
# Function: render_images at line 30
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#     30                                               def render_images(self, params, batch_size, as_numpy_array=False):
#     31         1    6895045.0 6895045.0     97.7          images = self._render_images(params, batch_size)
#     32         1     164327.0 164327.0      2.3          images = images.sum(dim=1, keepdim=True)
#     33         1         33.0     33.0      0.0          if as_numpy_array:
#     34                                                       images = images.detach().numpy()
#     35         1          7.0      7.0      0.0          return images
#
# Total time: 0.684288 s
# File: d:\github\smlm-dl\smlm_dl\model\renderer.py
# Function: _render_images at line 491
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    491                                               def _render_images(self, mapped_params, batch_size=None, raw=False):
#    492         1       2482.0   2482.0      0.0          shift_pixel = {key: torch.floor(mapped_params[key]/1).type(torch.int) for key in ['x', 'y', 'z']}
#    493         1       2239.0   2239.0      0.0          shifts_subpixel = {key: torch.remainder(mapped_params[key], 1) for key in ['x', 'y', 'z']}
#    494
#    495         1    5696352.0 5696352.0     83.2          template = self._calculate_template(shifts_subpixel, shift_pixel['z']+self.centering_offset[2])
#    496         1         28.0     28.0      0.0          if raw:
#    497                                                       return template
#    498
#    499         1      36350.0  36350.0      0.5          x_a = torch.zeros((shift_pixel['y'].shape[0], shift_pixel['y'].shape[1], self.out_size[0]+2, self.out_size[1]+2))
#    500
#    501         4     135570.0  33892.5      2.0          index = self.index_a.unsqueeze(0).unsqueeze(0) \
#    502         1         33.0     33.0      0.0                  + shift_pixel['y'] \
#    503         2        183.0     91.5      0.0                  + self.centering_offset[1] + 1
#    504         1      42518.0  42518.0      0.6          index = torch.clamp(index, 0, x_a.shape[3]-1)
#    505         1      39312.0  39312.0      0.6          x_a.scatter_(3, index, template)
#    506
#    507         1      47597.0  47597.0      0.7          x_b = torch.zeros_like(x_a)
#    508
#    509         4     427873.0 106968.2      6.3          index = self.index_b.unsqueeze(0).unsqueeze(0) \
#    510         1         41.0     41.0      0.0                  + shift_pixel['x'] \
#    511         2        179.0     89.5      0.0                  + self.centering_offset[0] + 1
#    512         1     166327.0 166327.0      2.4          index = torch.clamp(index, 0, x_b.shape[2]-1)
#    513         1     104510.0 104510.0      1.5          x_b.scatter_(2, index, x_a)
#    514
#    515         1        915.0    915.0      0.0          x = x_b[:,:,1:-1,1:-1]
#    516
#    517         1     140337.0 140337.0      2.1          x = x * mapped_params['A'] + mapped_params['bg']
#    518
#    519         1         35.0     35.0      0.0          return x
#
# Total time: 0.565505 s
# File: d:\github\smlm-dl\smlm_dl\model\renderer.py
# Function: _calculate_template at line 521
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#    521                                               def _calculate_template(self, shifts_subpixel, shift_pixel_z):
#    522         1     519370.0 519370.0      9.2          index = torch.arange(4).tile(*shift_pixel_z.shape[:2], *self.coeffs.shape[:2], 1) + self.offset + shift_pixel_z.unsqueeze(-1)
#    523         1     215233.0 215233.0      3.8          index = torch.clamp(index, 0, self.coeffs.shape[2]-1)
#    524
#    525         1     568501.0 568501.0     10.1          coeffs = self.coeffs.tile(*shift_pixel_z.shape[:2], 1, 1, 1)
#    526         1     242102.0 242102.0      4.3          coeffs = torch.gather(coeffs, 4, index)
#    527
#    528         2       6104.0   3052.0      0.1          bases = {'x': spline.calculate_bspline_basis(shifts_subpixel['x'], self.k),
#    529         1       4186.0   4186.0      0.1                   'y': spline.calculate_bspline_basis(shifts_subpixel['y'], self.k),
#    530         1       4589.0   4589.0      0.1                   'z': spline.calculate_bspline_basis(1-shifts_subpixel['z'], self.k),}
#    531         1         12.0     12.0      0.0          x = 0
#    532         5        157.0     31.4      0.0          for i, cx in enumerate(bases['x']):
#    533        20        630.0     31.5      0.0              for j, cy in enumerate(bases['y']):
#    534        80       6480.0     81.0      0.1                  for k, cz in enumerate(bases['z']):
#    535       128      65767.0    513.8      1.2                      coeffs_tmp = coeffs[:,:,
#    536        64       4765.0     74.5      0.1                                          i+self.offset:i+self.offset+self.template_size[0]+1,
#    537        64       1523.0     23.8      0.0                                          j+self.offset:j+self.offset+self.template_size[1]+1,
#    538        64        617.0      9.6      0.0                                          k]
#    539        64    4015012.0  62734.6     71.0                      x = x + cx * cy * cz * coeffs_tmp
#    540         1          7.0      7.0      0.0          return x

# %%
reload(renderer)
reload(model)

ref_psf = np.zeros((32,32,64))
ref_psf[14:16,14:16,31:33] = 1
n = 5
mapped_params = {'x': torch.linspace(-1, 1, n).reshape(-1, 1, 1, 1)*1,
                 # 'x': torch.zeros((n, 1, 1, 1)),
                 'y': torch.linspace(-16, 16, n).reshape(-1, 1, 1, 1)*0,
                 # 'z': torch.zeros((n, 1, 1, 1)),
                 'A': torch.ones((n, 1, 1, 1)),
                 'bg': torch.zeros((n, 1, 1, 1)),
                }
# print(mapped_params['x'].squeeze())

# print(ref_psf.shape)
spline_renderer = model.Spline2DRenderer(ref_psf.shape[:2], [], k=3, template_init=ref_psf[:,:,ref_psf.shape[2]//2])


pred = spline_renderer(mapped_params)
# print(pred.shape)

tiled_images = util.tile_images(pred.detach().numpy(), n)[0,0]
# print(tiled_images.min(), tiled_images.max())

fig, ax = subplots(1, 1, figsize=(n*4+3, 4))
im = ax.imshow(tiled_images, vmin=0, vmax=1)
colorbar(im, ax=ax)
ax.set_ylim(10, 20)
ax.axhline(15, c='red')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Early termination after 55 iterations, r2 tol < 0.001 reached
# Final loss: 0.000	R2: 0.999

# %%
reload(dataset)

psf_zerns = dict()
for z in range(3, 21):
    psf_zerns[z] = np.random.uniform(-0.5, 0.5)
psf_zerns.update({5:2 })

print(psf_zerns)

length = 64
image_params_preset = {'A': np.ones(length),
                       'x': np.zeros(length),
                       'y': np.zeros(length),
                       'bg': np.zeros(length),
                       'z': np.linspace(-31.5, 31.5, length)}
print(image_params_preset['z'])

settings = {
    # 'out_size': (64,64),
    # 'length': (length, 1),
    'dropout_p': 0,
    # 'psf_params': {'z':[-10,10]},
    'psf_zerns': psf_zerns,
    # 'noise_params': {},
    'normalize': False,
    # 'padding': (4,4),
    # 'random_z': True,
    "augmentations":{},
    # "augmentations":{"pixel shift":(4,4), }#"add noise":0.1},
}

reference_psf_data = dataset.FourierOpticsPSFDataset(length=64,
                                                     noise_params={},
                                                     image_params_preset=image_params_preset,
                                                    **settings)
dataset.inspect_images(reference_psf_data)
volume = np.asarray([image for (image, label) in reference_psf_data])
volume = volume[:,0,...]
volume = np.moveaxis(volume, 0, -1)
print(volume.shape)

ref_psf = volume[:,:,:]

fig, axes = subplots(1, 3, gridspec_kw={'width_ratios':[1, 2, 2]}, figsize=(15,3))
axes[0].imshow(volume[:,:,volume.shape[2]//2])
axes[1].imshow(volume[:,volume.shape[1]//2,:])
axes[2].imshow(volume[volume.shape[0]//2,:,:])
fig.tight_layout()

training_data = dataset.FourierOpticsPSFDataset(length = 128,
                                                psf_params={'z':[-10,10]},
                                                **settings)
# Out:
# {3: 0.23967318541826665, 4: -0.48791118220028884, 5: 2, 6: -0.47429932123744034, 7: 0.4666602368497962, 8: 0.1774741455185218, 9: -0.026402058397253847, 10: 0.4530181744854095, 11: -0.4729411656655621, 12: -0.1424781236412921, 13: 0.07734257283041457, 14: -0.4865511958394586, 15: -0.40888770523080853, 16: -0.24027562318522133, 17: 0.1648228464858854, 18: 0.2899079662455064, 19: -0.08231858017612625, 20: -0.1274652455298746}
# [-31.5 -30.5 -29.5 -28.5 -27.5 -26.5 -25.5 -24.5 -23.5 -22.5 -21.5 -20.5
#  -19.5 -18.5 -17.5 -16.5 -15.5 -14.5 -13.5 -12.5 -11.5 -10.5  -9.5  -8.5
#   -7.5  -6.5  -5.5  -4.5  -3.5  -2.5  -1.5  -0.5   0.5   1.5   2.5   3.5
#    4.5   5.5   6.5   7.5   8.5   9.5  10.5  11.5  12.5  13.5  14.5  15.5
#   16.5  17.5  18.5  19.5  20.5  21.5  22.5  23.5  24.5  25.5  26.5  27.5
#   28.5  29.5  30.5  31.5]
# 54:	 [id = 54.000,], [A = 1.000,], [bg = 0.000,], [x = 0.000,], [y = 0.000,], [z = 22.500,],
# 39:	 [id = 39.000,], [A = 1.000,], [bg = 0.000,], [x = 0.000,], [y = 0.000,], [z = 7.500,],
# 28:	 [id = 28.000,], [A = 1.000,], [bg = 0.000,], [x = 0.000,], [y = 0.000,], [z = -3.500,],
# 26:	 [id = 26.000,], [A = 1.000,], [bg = 0.000,], [x = 0.000,], [y = 0.000,], [z = -5.500,],
# 44:	 [id = 44.000,], [A = 1.000,], [bg = 0.000,], [x = 0.000,], [y = 0.000,], [z = 12.500,],
# 38:	 [id = 38.000,], [A = 1.000,], [bg = 0.000,], [x = 0.000,], [y = 0.000,], [z = 6.500,],
# 21:	 [id = 21.000,], [A = 1.000,], [bg = 0.000,], [x = 0.000,], [y = 0.000,], [z = -10.500,],
# 12:	 [id = 12.000,], [A = 1.000,], [bg = 0.000,], [x = 0.000,], [y = 0.000,], [z = -19.500,],
# (32, 32, 64)

# %%
reload(model.renderer)
reload(model)
# reload(trainer)
# ref_psf = np.zeros((32,32,64))
# ref_psf[14:16,14:16,31:33] = 1
fitting_model = model.BaseFitModel(renderer_class=model.Spline3DRenderer,
                                   encoder_class=model.ConvImageEncoderModel,
                                   fit_params=['x','y','A','bg','z'],
                                   renderer_params={'k':3,
                                                    'template_init':ref_psf,
                                                   }
                                     )

volume = fitting_model.renderer.render(4).detach().numpy()

fig, axes = subplots(1, 3, gridspec_kw={'width_ratios':[1, 2, 2]}, figsize=(25,5))
axes[0].imshow(volume[:,:,volume.shape[2]//2])
axes[1].imshow(volume[:,volume.shape[1]//2,:])
axes[2].imshow(volume[volume.shape[0]//2,:,:])
fig.tight_layout()

# %%
n = 5
mapped_params = {'x': torch.linspace(-1, 1, n).reshape(-1, 1, 1, 1)*1,
                 # 'x': torch.zeros((n, 1, 1, 1)),
                 'y': torch.linspace(-16, 16, n).reshape(-1, 1, 1, 1)*0,
                 'z': torch.zeros((n, 1, 1, 1)),
                 'A': torch.ones((n, 1, 1, 1)),
                 'bg': torch.zeros((n, 1, 1, 1)),
                }
print(mapped_params['x'].squeeze())

pred = fitting_model.renderer(mapped_params)
print(pred.shape)

tiled_images = util.tile_images(pred.detach().numpy(), n)[0,0]
print(tiled_images.min(), tiled_images.max())

fig, ax = subplots(1, 1, figsize=(n*4+3, 4))
im = ax.imshow(tiled_images, vmin=0, vmax=1)
colorbar(im, ax=ax)
ax.set_ylim(10, 20)
ax.axhline(15, c='red')
