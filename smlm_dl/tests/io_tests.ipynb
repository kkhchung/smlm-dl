# %%
from importlib import reload
import os
# import tifffile

# import skimage.io
# import zipfile
# from PIL import Image

from smlm_dl import config, dataset, fileloader
# from torch.utils.data import Dataset

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# http://gigadb.org/dataset/view/id/100888
path_zip_of_tif = os.path.join(config.config["TEST_DATASET_PATH"]["epfl"], "CElegans-CY3.zip")

# http://bigwww.epfl.ch/deconvolution/bio/
path_multiframe_tif = os.path.join(config.config["TEST_DATASET_PATH"]["hagen"], "01-mito-60x-noise1", "mito-60x-noise1-lowsnr.tif")

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_zip_of_tif, fileloader.ZipSkImageFileLoader, slices=(slice(100,-100),slice(100,-100)), stack_to_volume=False, cache=False)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\epfl\CElegans-CY3.zip, frames: 104, image shape: (1, 512, 472)
# 46:	 [id = 46.000,],
# 12:	 [id = 12.000,],
# 71:	 [id = 71.000,],
# 0:	 [id = 0.000,],
# 32:	 [id = 32.000,],
# 85:	 [id = 85.000,],
# 57:	 [id = 57.000,],
# 96:	 [id = 96.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_zip_of_tif, fileloader.ZipSkImageFileLoader, slices=(slice(100,-100),slice(100,-100)), stack_to_volume=False, cache=True)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\epfl\CElegans-CY3.zip, frames: 104, image shape: (1, 512, 472)
# 60:	 [id = 60.000,],
# 73:	 [id = 73.000,],
# 51:	 [id = 51.000,],
# 41:	 [id = 41.000,],
# 33:	 [id = 33.000,],
# 17:	 [id = 17.000,],
# 22:	 [id = 22.000,],
# 94:	 [id = 94.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_zip_of_tif, fileloader.ZipSkImageFileLoader, slices=(slice(200,-200),slice(200,-200),slice(25,-25)), stack_to_volume=True, cache=False)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\epfl\CElegans-CY3.zip, frames: 1, image shape: (1, 312, 272, 54)
# 0:	 [id = 0.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_zip_of_tif, fileloader.ZipSkImageFileLoader, slices=(slice(200,-200),slice(200,-200),slice(25,-25)), stack_to_volume=True, cache=True)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\epfl\CElegans-CY3.zip, frames: 1, image shape: (1, 312, 272, 54)
# 0:	 [id = 0.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_multiframe_tif, fileloader.SkImageFileLoader, slices=(slice(512,-512),slice(512,-512)), stack_to_volume=False, cache=False)

dataset.inspect_images(test_dataset)
# Out:
# The file is always loaded to memory with SkImageFileLoader
# filepath: D:\PublicDatasets\hagen\01-mito-60x-noise1\mito-60x-noise1-lowsnr.tif, frames: 100, image shape: (1, 1024, 1024)
# 85:	 [id = 85.000,],
# 42:	 [id = 42.000,],
# 28:	 [id = 28.000,],
# 59:	 [id = 59.000,],
# 75:	 [id = 75.000,],
# 62:	 [id = 62.000,],
# 88:	 [id = 88.000,],
# 70:	 [id = 70.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_multiframe_tif, fileloader.SkImageFileLoader, slices=(slice(512,-512),slice(512,-512)), stack_to_volume=False, cache=True)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\hagen\01-mito-60x-noise1\mito-60x-noise1-lowsnr.tif, frames: 100, image shape: (1, 1024, 1024)
# 68:	 [id = 68.000,],
# 38:	 [id = 38.000,],
# 6:	 [id = 6.000,],
# 52:	 [id = 52.000,],
# 33:	 [id = 33.000,],
# 94:	 [id = 94.000,],
# 35:	 [id = 35.000,],
# 32:	 [id = 32.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_multiframe_tif, fileloader.SkImageFileLoader, slices=(slice(512,-512),slice(512,-512),slice(25,-25)), stack_to_volume=True, cache=False)

dataset.inspect_images(test_dataset)
# Out:
# The file is always loaded to memory with SkImageFileLoader
# filepath: D:\PublicDatasets\hagen\01-mito-60x-noise1\mito-60x-noise1-lowsnr.tif, frames: 1, image shape: (1, 1024, 1024, 50)
# 0:	 [id = 0.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_multiframe_tif, fileloader.SkImageFileLoader, slices=(slice(512,-512),slice(512,-512),slice(25,-25)), stack_to_volume=True, cache=True)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\hagen\01-mito-60x-noise1\mito-60x-noise1-lowsnr.tif, frames: 1, image shape: (1, 1024, 1024, 50)
# 0:	 [id = 0.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_multiframe_tif, fileloader.PilImageFileLoader, slices=(slice(512,-512),slice(512,-512)), stack_to_volume=False, cache=False)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\hagen\01-mito-60x-noise1\mito-60x-noise1-lowsnr.tif, frames: 100, image shape: (1, 1024, 1024)
# 60:	 [id = 60.000,],
# 69:	 [id = 69.000,],
# 82:	 [id = 82.000,],
# 86:	 [id = 86.000,],
# 64:	 [id = 64.000,],
# 58:	 [id = 58.000,],
# 5:	 [id = 5.000,],
# 9:	 [id = 9.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_multiframe_tif, fileloader.PilImageFileLoader, slices=(slice(512,-512),slice(512,-512)), stack_to_volume=False, cache=True)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\hagen\01-mito-60x-noise1\mito-60x-noise1-lowsnr.tif, frames: 100, image shape: (1, 1024, 1024)
# 42:	 [id = 42.000,],
# 57:	 [id = 57.000,],
# 2:	 [id = 2.000,],
# 0:	 [id = 0.000,],
# 36:	 [id = 36.000,],
# 51:	 [id = 51.000,],
# 4:	 [id = 4.000,],
# 33:	 [id = 33.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_multiframe_tif, fileloader.PilImageFileLoader, slices=(slice(512,-512),slice(512,-512),slice(25,-25)), stack_to_volume=True, cache=False)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\hagen\01-mito-60x-noise1\mito-60x-noise1-lowsnr.tif, frames: 1, image shape: (1, 1024, 1024, 50)
# 0:	 [id = 0.000,],

# %%
reload(dataset)
reload(fileloader)

test_dataset = dataset.FileWrapperDataset(path_multiframe_tif, fileloader.PilImageFileLoader, slices=(slice(512,-512),slice(512,-512),slice(25,-25)), stack_to_volume=True, cache=True)

dataset.inspect_images(test_dataset)
# Out:
# filepath: D:\PublicDatasets\hagen\01-mito-60x-noise1\mito-60x-noise1-lowsnr.tif, frames: 1, image shape: (1, 1024, 1024, 50)
# 0:	 [id = 0.000,],
